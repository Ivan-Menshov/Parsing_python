# %%
from pprint import pprint
from lxml import html
import requests

# %%
url = 'https://lenta.ru'


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.167 YaBrowser/22.7.5.1027 Yowser/2.5 Safari/537.36',
}

response = requests.get(url, headers=headers)
pprint(response.text)
# Out:
# ('<!DOCTYPE html><html lang="ru"><head><title>Lenta.ru - Новости России и мира '
#  'сегодня</title><meta charset="utf-8" /><meta content="#292929" '
#  'name="theme-color" /><link href="https://m.lenta.ru/" media="only screen and '
#  '(max-width: 640px)" rel="alternate" /><link '
#  'href="https://lenta.ru/rss/google-newsstand/main/" rel="alternate" '
#  'type="application/rss+xml" /><link href="https://lenta.ru/" rel="canonical" '
#  '/><link href="/manifest.json" rel="manifest" /><link rel="shortcut icon" '
#  'type="image/x-icon" href="https://icdn.lenta.ru/favicon.ico" /><link '
#  'rel="apple-touch-icon" type="image/x-icon" '
#  'href="https://icdn.lenta.ru/images/icons/icon-256x256.png" size="256x256" '
#  '/><link rel="apple-touch-icon" type="image/x-icon" '
#  'href="https://icdn.lenta.ru/images/icons/icon-192x192.png" size="192x192" '
#  '/><link rel="apple-touch-icon" type="image/x-icon" '
#  'href="https://icdn.lenta.ru/images/icons/icon-152x152.png" size="152x152" '
# ...

# %%
dom = html.fromstring(response.text)
news_links =  dom.xpath("//div[@class='longgrid-list__box']/a[@class='card-mini _longgrid']/@href")
news_name = dom.xpath("//div[@class='longgrid-list__box']/a[@class='card-mini _longgrid']/div/span/text()")
news_time =  dom.xpath("//div[@class='longgrid-list__box']/a[@class='card-mini _longgrid']/div/div/time/text()")

# %%
news ={}
for i in range(len(news_name)):
    news[i] = {
        'news_name':news_name[i],
        'news_links ':url+news_links[i] ,
        'news_time':news_time[i],
    }

# %%
news
# Out:
# {0: {'news_name': 'Путин призвал выстраивать эффективные экономические связи в России',
#   'news_links ': 'https://lenta.ru/news/2023/02/21/effective/',
#   'news_time': '13:34'},
#  1: {'news_name': 'Путин назвал последствия смены системы образования для студентов и выпускников',
#   'news_links ': 'https://lenta.ru/news/2023/02/21/prodolzhat/',
#   'news_time': '13:34'},
#  2: {'news_name': 'Названы главные «фишки» московского языка 90-х',
#   'news_links ': 'https://lenta.ruhttps://moslenta.ru/news/city/fishki-yazyka-90-kh-21-02-2023.htm/',
#   'news_time': '13:33'},
#  3: {'news_name': 'Врач раскрыла россиянкам шесть правил питания для избавления от целлюлита',
#   'news_links ': 'https://lenta.ru/news/2023/02/21/cellulite1/',
#   'news_time': '13:32'},
#  4: {'news_name': 'Путин заявил о наращивании развития новых регионов',
#   'news_links ': 'https://lenta.ru/news/2023/02/21/newregioni/',
#   'news_time': '13:32'},
# ...
